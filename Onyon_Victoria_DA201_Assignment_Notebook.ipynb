# %% [markdown]
# ### LSE Data Analytics Online Career Accelerator
#
# # Course 2: Data Analytics using Python

# %% [markdown]
# ## Assignment: Diagnostic Analysis using Python
#
# You’ll be working with real-world data to address a problem faced by the National Health Service (NHS). The analysis will require you to utilise Python to explore the available data, create visualisations to identify trends, and extract meaningful insights to inform decision-making.

# %% [markdown]
# ### A note for students using this template
# This Jupyter Notebook is a template you can use to complete the Course 2 assignment: Diagnostic Analysis using Python.
#
# Keep in mind:
# - You are **not required** to use this template to complete the assignment.
# - If you decide to use this template for your assignment, make a copy of the notebook and save it using the assignment naming convention: **LastName_FirstName_DA201_Assignment_Notebook.ipynb**.
# - The workflow suggested in this template follows the Assignment Activities throughout the course.
# - Refer to the guidance on the Assignment Activity pages for specific details.
# - The markup and comments in this template identify the key elements you need to complete before submitting the assignment.
# - Make this notebook your own by adding your process notes and rationale using markdown, add links, screenshots, or images to support your analysis, refine or clarify the comments, and change the workflow to suit your process.
# - All elements should be functional and visible in your Notebook.
# - Be sure to push your notebook to GitHub after completing each Assignment Activity.
#
#  > ***Markdown*** Remember to change cell types to `Markdown`. You can review [Markdown basics](https://docs.github.com/en/get-started/writing-on-github/getting-started-with-writing-and-formatting-on-github/basic-writing-and-formatting-syntax) to find out how to add formatted text, links, and images to your notebook.

# %% [markdown]
# #

# %% [markdown]
# # Assignment activity 1

# %% [markdown]
# ### Insert proof of your GitHub repository. This can be a link or screenshot showing your repo.

# %% [markdown]
# # My GitHub repository:
# https://github.com/victoriaonyon/LSE_DA_NHS_analysis_project

# %% [markdown]
# # Assignment activity 2

# %% [markdown]
# ### Exploratory Data Analysis of the three datasets

# %%
# Import the necessary libraries.

import pandas as pd
import numpy as np
from datetime import datetime
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Import and sense-check the actual_duration.csv data set
actual_duration = pd.read_csv('actual_duration.csv')

# Check shape, datatypes and view snapshot of the DataFrame
print(actual_duration.shape)
print(actual_duration.dtypes)
actual_duration.head()
# Out:
# (137793, 8)
# sub_icb_location_code        object
# sub_icb_location_ons_code    object
# sub_icb_location_name        object
# icb_ons_code                 object
# region_ons_code              object
# appointment_date             object
# actual_duration              object
# count_of_appointments         int64
# dtype: object
#   sub_icb_location_code sub_icb_location_ons_code  \
# 0                   00L                 E38000130
# 1                   00L                 E38000130
# 2                   00L                 E38000130
# 3                   00L                 E38000130
# 4                   00L                 E38000130
#
#                         sub_icb_location_name icb_ons_code region_ons_code  \
# 0  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 1  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 2  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# ...

# %%
# Determine whether there are missing values using isna()
actual_duration.isna().sum()
# Out:
# sub_icb_location_code        0
# sub_icb_location_ons_code    0
# sub_icb_location_name        0
# icb_ons_code                 0
# region_ons_code              0
# appointment_date             0
# actual_duration              0
# count_of_appointments        0
# dtype: int64

# %%
# Determine the metadata of the data set.
actual_duration.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137793 entries, 0 to 137792
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   sub_icb_location_code      137793 non-null  object
#  1   sub_icb_location_ons_code  137793 non-null  object
#  2   sub_icb_location_name      137793 non-null  object
#  3   icb_ons_code               137793 non-null  object
#  4   region_ons_code            137793 non-null  object
#  5   appointment_date           137793 non-null  object
#  6   actual_duration            137793 non-null  object
#  7   count_of_appointments      137793 non-null  int64
# dtypes: int64(1), object(7)
# memory usage: 8.4+ MB

# %%
# Determine the descriptive statistics of the data set.
actual_duration.describe()
# Out:
#        count_of_appointments
# count          137793.000000
# mean             1219.080011
# std              1546.902956
# min                 1.000000
# 25%               194.000000
# 50%               696.000000
# 75%              1621.000000
# max             15400.000000

# %%
# Import and sense-check the appointments_regional.csv data set as ar.
appointments_regional = pd.read_csv('appointments_regional.csv')

# Check the shape and datatypes, and view first lines of the DataFrame
print(appointments_regional.shape)
print(appointments_regional.dtypes)
appointments_regional.head()
# Out:
# (596821, 7)
# icb_ons_code                         object
# appointment_month                    object
# appointment_status                   object
# hcp_type                             object
# appointment_mode                     object
# time_between_book_and_appointment    object
# count_of_appointments                 int64
# dtype: object
#   icb_ons_code appointment_month appointment_status hcp_type appointment_mode  \
# 0    E54000034           2020-01           Attended       GP     Face-to-Face
# 1    E54000034           2020-01           Attended       GP     Face-to-Face
# 2    E54000034           2020-01           Attended       GP     Face-to-Face
# 3    E54000034           2020-01           Attended       GP     Face-to-Face
# 4    E54000034           2020-01           Attended       GP     Face-to-Face
#
#   time_between_book_and_appointment  count_of_appointments
# 0                             1 Day                   8107
# ...

# %%
# Determine whether there are missing values.
appointments_regional.isna().sum()
# Out:
# icb_ons_code                         0
# appointment_month                    0
# appointment_status                   0
# hcp_type                             0
# appointment_mode                     0
# time_between_book_and_appointment    0
# count_of_appointments                0
# dtype: int64

# %%
# Determine the metadata of the data set.
appointments_regional.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 596821 entries, 0 to 596820
# Data columns (total 7 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   icb_ons_code                       596821 non-null  object
#  1   appointment_month                  596821 non-null  object
#  2   appointment_status                 596821 non-null  object
#  3   hcp_type                           596821 non-null  object
#  4   appointment_mode                   596821 non-null  object
#  5   time_between_book_and_appointment  596821 non-null  object
#  6   count_of_appointments              596821 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 31.9+ MB

# %%
# Determine the descriptive statistics of the data set.
appointments_regional.describe()
# Out:
#        count_of_appointments
# count          596821.000000
# mean             1244.601857
# std              5856.887042
# min                 1.000000
# 25%                 7.000000
# 50%                47.000000
# 75%               308.000000
# max            211265.000000

# %%
# Import and sense-check the national_categories.xlsx data set as nc.
national_categories = pd.read_excel('national_categories.xlsx')

# Check the shape, datatypes and view the DataFrame.

print(national_categories.shape)
print(national_categories.dtypes)
national_categories.head()
# Out:
# (817394, 8)
# appointment_date         datetime64[ns]
# icb_ons_code                     object
# sub_icb_location_name            object
# service_setting                  object
# context_type                     object
# national_category                object
# count_of_appointments             int64
# appointment_month                object
# dtype: object
#   appointment_date icb_ons_code                       sub_icb_location_name  \
# 0       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 1       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 2       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 3       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 4       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
#
#         service_setting            context_type  \
# 0  Primary Care Network  Care Related Encounter
# 1                 Other  Care Related Encounter
# ...

# %%
# Determine whether there are missing values.
national_categories.isna().sum()
# Out:
# appointment_date         0
# icb_ons_code             0
# sub_icb_location_name    0
# service_setting          0
# context_type             0
# national_category        0
# count_of_appointments    0
# appointment_month        0
# dtype: int64

# %%
# Determine the metadata of the data set.
national_categories.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 817394 entries, 0 to 817393
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   appointment_date       817394 non-null  datetime64[ns]
#  1   icb_ons_code           817394 non-null  object
#  2   sub_icb_location_name  817394 non-null  object
#  3   service_setting        817394 non-null  object
#  4   context_type           817394 non-null  object
#  5   national_category      817394 non-null  object
#  6   count_of_appointments  817394 non-null  int64
#  7   appointment_month      817394 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(6)
# memory usage: 49.9+ MB

# %%
# Determine the descriptive statistics of the data set.
national_categories.describe()
# Out:
#        count_of_appointments
# count          817394.000000
# mean              362.183684
# std              1084.576600
# min                 1.000000
# 25%                 7.000000
# 50%                25.000000
# 75%               128.000000
# max             16590.000000

# %% [markdown]
# ### Explore the data set

# %% [markdown]
# **Question 1:** How many locations are there in the data set?

# %%
# Using the NC dataset - determine the number of locations using value_counts()
# Data is sorted in desc order using value_counts()

national_categories['sub_icb_location_name'].value_counts()
# Out:
# NHS North West London ICB - W2U3Z              13007
# NHS Kent and Medway ICB - 91Q                  12637
# NHS Devon ICB - 15N                            12526
# NHS Hampshire and Isle Of Wight ICB - D9Y0V    12171
# NHS North East London ICB - A3A8R              11837
#                                                ...
# NHS North East and North Cumbria ICB - 00N      4210
# NHS Lancashire and South Cumbria ICB - 02G      4169
# NHS Cheshire and Merseyside ICB - 01V           3496
# NHS Cheshire and Merseyside ICB - 01T           3242
# NHS Greater Manchester ICB - 00V                2170
# Name: sub_icb_location_name, Length: 106, dtype: int64

# %% [markdown]
# There are 106 different locations in the data set

# %% [markdown]
# **Question 2:** What are the five locations with the highest number of records?

# %%
# Determine the top five locations based on record count using iloc
national_categories['sub_icb_location_name'].value_counts().iloc[0:5]
# Out:
# NHS North West London ICB - W2U3Z              13007
# NHS Kent and Medway ICB - 91Q                  12637
# NHS Devon ICB - 15N                            12526
# NHS Hampshire and Isle Of Wight ICB - D9Y0V    12171
# NHS North East London ICB - A3A8R              11837
# Name: sub_icb_location_name, dtype: int64

# %%
# The most popular location found using value_counts.idxmax()
national_categories['sub_icb_location_name'].value_counts().idxmax()

print(f"The location with the most appointments is \
{national_categories['sub_icb_location_name'].value_counts().idxmax()}")
# Out:
# The location with the most appointments is NHS North West London ICB - W2U3Z

# %% [markdown]
# **Question 3:** How many service settings, context types, national categories, and appointment statuses are there?

# %%
# Determine the number of service settings, context types and national categories 
# Used nunique as this prints a count for all categories with one line of code
national_categories.nunique()
# Out:
# appointment_date          334
# icb_ons_code               42
# sub_icb_location_name     106
# service_setting             5
# context_type                3
# national_category          18
# count_of_appointments    9957
# appointment_month          11
# dtype: int64

# %% [markdown]
# There are 5 service settings, 3 context types and 18 national categories

# %%
# Determine the number of appointment statuses
appointments_regional['appointment_status'].value_counts()
# Out:
# Attended    232137
# Unknown     201324
# DNA         163360
# Name: appointment_status, dtype: int64

# %% [markdown]
# # Assignment activity 3

# %% [markdown]
# ### Continue to explore the data and search for answers to more specific questions posed by the NHS.

# %% [markdown]
# **Question 1:** Between what dates were appointments scheduled?

# %%
# View the first five rows of appointment_date for the ad DataFrame to determine the date format.
print(actual_duration['appointment_date'].dtype)
actual_duration['appointment_date'].head()
# Out:
# object
# 0    01-Dec-21
# 1    01-Dec-21
# 2    01-Dec-21
# 3    01-Dec-21
# 4    01-Dec-21
# Name: appointment_date, dtype: object

# %%
# View the first five rows of appointment_date for the nc DataFrame to determine the date format.
print(national_categories['appointment_month'].dtypes)
national_categories.head()
# Out:
# object
#   appointment_date icb_ons_code                       sub_icb_location_name  \
# 0       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 1       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 2       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 3       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 4       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
#
#         service_setting            context_type  \
# 0  Primary Care Network  Care Related Encounter
# 1                 Other  Care Related Encounter
# 2      General Practice  Care Related Encounter
# 3      General Practice  Care Related Encounter
# 4      General Practice  Care Related Encounter
#
#                         national_category  count_of_appointments  \
# 0  Patient contact during Care Home Round                      3
# 1                         Planned Clinics                      7
# ...

# %%
# Change the date format of ad['appointment_date'].
actual_duration['appointment_date'] = pd.to_datetime(actual_duration['appointment_date'])

# View the data types.
actual_duration.dtypes
# Out:
# sub_icb_location_code                object
# sub_icb_location_ons_code            object
# sub_icb_location_name                object
# icb_ons_code                         object
# region_ons_code                      object
# appointment_date             datetime64[ns]
# actual_duration                      object
# count_of_appointments                 int64
# dtype: object

# %%
# Change the date format of ar['appointment_date'].
appointments_regional['appointment_month'] = pd.to_datetime(appointments_regional['appointment_month'])

# View the data types.
appointments_regional.dtypes
# Out:
# icb_ons_code                                 object
# appointment_month                    datetime64[ns]
# appointment_status                           object
# hcp_type                                     object
# appointment_mode                             object
# time_between_book_and_appointment            object
# count_of_appointments                         int64
# dtype: object

# %%
# Determine the minimum and maximum dates in the ad DataFrame.
# Use appropriate docstrings.
print(f"The minimum date value in the actual duration dataframe is {actual_duration['appointment_date'].min()}")
print(f"The maximum date value in the actual duration is {actual_duration['appointment_date'].max()}")
# Out:
# The minimum date value in the actual duration dataframe is 2021-12-01 00:00:00
# The maximum date value in the actual duration is 2022-06-30 00:00:00

# %%
# Determine the minimum and maximum dates in the nc DataFrame.
# Use appropriate docstrings.
print(f"The minimum date value in the NC dataframe is {national_categories['appointment_date'].min()}")
print(f"The maximum date value in the NC dataframe is {national_categories['appointment_date'].max()}")
# Out:
# The minimum date value in the NC dataframe is 2021-08-01 00:00:00
# The maximum date value in the NC dataframe is 2022-06-30 00:00:00

# %%
# Determine the minimum and maximum dates in the nc DataFrame.
# Use appropriate docstrings.
print(f"The minimum date value in the ar dataframe is {appointments_regional['appointment_month'].min()}")
print(f"The maximum date value in the ar dataframe is {appointments_regional['appointment_month'].max()}")
# Out:
# The minimum date value in the ar dataframe is 2020-01-01 00:00:00
# The maximum date value in the ar dataframe is 2022-06-01 00:00:00

# %% [markdown]
# **Question 2:** Which service setting was the most popular for NHS North West London from 1 January to 1 June 2022?

# %%
# Create a DataFrame filtered to NHS North West London from 1 January to 1 June 2022
nc_nwl = national_categories.loc[(national_categories["sub_icb_location_name"] ==\
                                    'NHS North West London ICB - W2U3Z') & \
                                    (national_categories["appointment_date"].between('2022-01-01','2022-06-01'))]

# View the output.
nc_nwl
# Out:
#        appointment_date icb_ons_code              sub_icb_location_name  \
# 800289       2022-01-01    E54000027  NHS North West London ICB - W2U3Z
# 800290       2022-01-01    E54000027  NHS North West London ICB - W2U3Z
# 800291       2022-01-01    E54000027  NHS North West London ICB - W2U3Z
# 800292       2022-01-01    E54000027  NHS North West London ICB - W2U3Z
# 800293       2022-01-01    E54000027  NHS North West London ICB - W2U3Z
# ...                 ...          ...                                ...
# 806220       2022-06-01    E54000027  NHS North West London ICB - W2U3Z
# 806221       2022-06-01    E54000027  NHS North West London ICB - W2U3Z
# 806222       2022-06-01    E54000027  NHS North West London ICB - W2U3Z
# 806223       2022-06-01    E54000027  NHS North West London ICB - W2U3Z
# 806224       2022-06-01    E54000027  NHS North West London ICB - W2U3Z
#
#                   service_setting            context_type  \
# ...

# %%
# Determine the number of records available for each service setting for NHS North West London
# Used groupby and sum to count number of records per service setting of NWL DataFrame

nc_nwl.groupby('service_setting')[['count_of_appointments']]\
.sum().reset_index().copy()
# Out:
#              service_setting  count_of_appointments
# 0  Extended Access Provision                  98159
# 1           General Practice                4804239
# 2                      Other                 152897
# 3       Primary Care Network                 109840
# 4                   Unmapped                 391106

# %% [markdown]
# **Question 3:** Which month had the highest number of appointments?

# %%
# Number of appointments per month == sum of count_of_appointments by month.
# Use the groupby() and sort_values() functions by ascending order
# Created a DataFrame to able to easily recall the count of appts by month

nc_monthly = national_categories.groupby(['appointment_month'])[['count_of_appointments']]\
.sum().reset_index().copy()

# View output.
nc_monthly.head()
# Out:
#   appointment_month  count_of_appointments
# 0           2021-08               23852171
# 1           2021-09               28522501
# 2           2021-10               30303834
# 3           2021-11               30405070
# 4           2021-12               25140776

# %%
# Sorted the NC monthly DataFrame to list the months by count of appots
nc_monthly.sort_values(by="count_of_appointments",ascending=False)
# Out:
#    appointment_month  count_of_appointments
# 3            2021-11               30405070
# 2            2021-10               30303834
# 7            2022-03               29595038
# 1            2021-09               28522501
# 9            2022-05               27495508
# 10           2022-06               25828078
# 5            2022-01               25635474
# 6            2022-02               25355260
# 4            2021-12               25140776
# 8            2022-04               23913060
# 0            2021-08               23852171

# %% [markdown]
# November 2021 had the most appointments whereas August 2021 had the least amount of appointments

# %% [markdown]
# **Question 4:** What was the total number of records per month?

# %%
# Total number of records per month by service setting
# Sorted count of appointment by service setting by month
nc_monthly = national_categories.groupby(['appointment_month', 'service_setting'])[['count_of_appointments']]\
.sum().reset_index().copy()

nc_monthly.head()
# Out:
#   appointment_month            service_setting  count_of_appointments
# 0           2021-08  Extended Access Provision                 160927
# 1           2021-08           General Practice               21575852
# 2           2021-08                      Other                 449101
# 3           2021-08       Primary Care Network                 432448
# 4           2021-08                   Unmapped                1233843

# %%
nctotal_appointments = national_categories.groupby('appointment_month')[['count_of_appointments']]\
.sum().reset_index().copy()

nctotal_appointments.rename(columns = {'count_of_appointments':'total'}, inplace = True)
nctotal_appointments['service_setting'] = 'total'
nctotal_appointments.head()
# Out:
#   appointment_month     total service_setting
# 0           2021-08  23852171           total
# 1           2021-09  28522501           total
# 2           2021-10  30303834           total
# 3           2021-11  30405070           total
# 4           2021-12  25140776           total

# %%
nc_total = nctotal_appointments[['appointment_month','service_setting', 'total']]
nc_total
# Out:
#    appointment_month service_setting     total
# 0            2021-08           total  23852171
# 1            2021-09           total  28522501
# 2            2021-10           total  30303834
# 3            2021-11           total  30405070
# 4            2021-12           total  25140776
# 5            2022-01           total  25635474
# 6            2022-02           total  25355260
# 7            2022-03           total  29595038
# 8            2022-04           total  23913060
# 9            2022-05           total  27495508
# 10           2022-06           total  25828078

# %% [markdown]
# Question 5: Which service setting has the most appointments?

# %%
# Count of each service settings 
national_categories.groupby('service_setting')[['count_of_appointments']]\
.sum().sort_values('count_of_appointments', ascending=False)
# Out:
#                            count_of_appointments
# service_setting
# General Practice                       270811691
# Unmapped                                11080810
# Primary Care Network                     6557386
# Other                                    5420076
# Extended Access Provision                2176807

# %% [markdown]
# #

# %% [markdown]
# # Assignment activity 4

# %% [markdown]
# ### Create visualisations and identify possible monthly and seasonal trends in the data.

# %%
# Set figure size.
sns.set(rc={'figure.figsize':(15, 12)})

# Set the plot style as white.
sns.set_style('white')

# %% [markdown]
# ### Objective 1
# Create three visualisations indicating the number of appointments per month for service settings, context types, and national categories.

# %%
# Check the datatypes of appointment date in case changes need to be made
print(national_categories.dtypes)
# Out:
# appointment_date         datetime64[ns]
# icb_ons_code                     object
# sub_icb_location_name            object
# service_setting                  object
# context_type                     object
# national_category                object
# count_of_appointments             int64
# appointment_month                object
# dtype: object

# %%
# Aggregate on monthly level and determine the sum of service records per month.
nc_monthly = national_categories.groupby(['appointment_month'])[['count_of_appointments']]\
.sum().reset_index().copy()

# View output.
nc_monthly.head()
# Out:
#   appointment_month  count_of_appointments
# 0           2021-08               23852171
# 1           2021-09               28522501
# 2           2021-10               30303834
# 3           2021-11               30405070
# 4           2021-12               25140776

# %% [markdown]
# **Service settings:**

# %%
# Plot the appointments over the available date range, and review the service settings for months.
# Create a lineplot.
plt.figure(figsize = (18, 6))
nc_plot = sns.lineplot(x='appointment_month', y='count_of_appointments', data=nc_monthly, ci=None)
plt.title("Monthly Appointment Count")
plt.xlabel("Appointment Month", fontsize= 12)
plt.ylabel("Count of Appointments", fontsize= 12)
# Out:
# Text(0, 0.5, 'Count of Appointments')

# %% [markdown]
# **Context types:**

# %%
# Create a separate data set that can be used in future weeks. 
ct = national_categories.groupby(['context_type', 'appointment_month'])[['count_of_appointments']]\
.sum().sort_values('context_type', ascending=False)


# View output.
ct.head()
# Out:
#                                 count_of_appointments
# context_type appointment_month
# Unmapped     2022-06                           758640
#              2022-05                           820770
#              2022-04                           760313
#              2022-03                           942912
#              2022-02                           811246

# %%
# Plot the appointments over the available date range, and review the context types for months.
# Create a lineplot.
plt.figure(figsize = (18, 6))

ct = sns.lineplot(x='appointment_month', y='count_of_appointments', hue='context_type', data=ct, ci=None)
plt.title("Appointment Count by Context Type")
plt.xlabel("Appointment Date", fontsize= 12)
plt.ylabel("Count of Appointments", fontsize= 12)
# Out:
# Text(0, 0.5, 'Count of Appointments')

# %% [markdown]
# **National categories:**

# %%
# Create a separate data set that can be used in future weeks. 
nc_nc = national_categories.groupby(['national_category', 'appointment_month'])\
[['count_of_appointments']].sum().reset_index().copy()


# View output.
nc_nc.head()
# Out:
#                                                      national_category  \
# 0  Care Home Needs Assessment & Personalised Care and Support Planning
# 1  Care Home Needs Assessment & Personalised Care and Support Planning
# 2  Care Home Needs Assessment & Personalised Care and Support Planning
# 3  Care Home Needs Assessment & Personalised Care and Support Planning
# 4  Care Home Needs Assessment & Personalised Care and Support Planning
#
#   appointment_month  count_of_appointments
# 0           2021-08                  29676
# 1           2021-09                  33503
# 2           2021-10                  32441
# 3           2021-11                  38827
# 4           2021-12                  34653

# %%
# Plot the appointments over the available date range, and review the national categories for months.
# Create a lineplot.
plt.figure(figsize = (18, 10))

nc_plot = sns.lineplot(x='appointment_month', y='count_of_appointments', hue='national_category',
                       data=nc_nc, ci=None)
plt.title("Appointment Count by National Category Types")
plt.xlabel("Appointment Date", fontsize= 12)
plt.ylabel("Count of Appointments (10,000s)", fontsize= 12)
# Out:
# Text(0, 0.5, 'Count of Appointments (10,000s)')

# %% [markdown]
# ### Objective 2
# Create four visualisations indicating the number of appointments for service setting per season. The seasons are summer (August 2021), autumn (October 2021), winter (January 2022), and spring (April 2022).

# %% [markdown]
# **Summer (August 2021):**

# %%
# Create a separate data set that can be used in future weeks. 
nc_august = national_categories[(national_categories['appointment_date'] >='2021-08-01') & \
                                (national_categories['appointment_date'] <='2021-08-31')]

# View output.
print(nc_august.shape)
nc_august.head()
# Out:
# (69999, 8)
#   appointment_date icb_ons_code                       sub_icb_location_name  \
# 0       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 1       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 2       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 3       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 4       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
#
#         service_setting            context_type  \
# 0  Primary Care Network  Care Related Encounter
# 1                 Other  Care Related Encounter
# 2      General Practice  Care Related Encounter
# 3      General Practice  Care Related Encounter
# 4      General Practice  Care Related Encounter
#
#                         national_category  count_of_appointments  \
# 0  Patient contact during Care Home Round                      3
# 1                         Planned Clinics                      7
# ...

# %%
# Look at August 2021 in more detail to allow a closer look.
# Create a lineplot.
plt.figure(figsize = (18, 6))

nc_plot = sns.lineplot(x='appointment_date', y='count_of_appointments', hue='service_setting',
                       data=nc_august, ci=None)
plt.title("August 2021 appointment count by service setting")
plt.xlabel("Appointment Date", fontsize= 12)
plt.ylabel("Count of Appointments", fontsize= 12)
# Out:
# Text(0, 0.5, 'Count of Appointments')

# %% [markdown]
# **Autumn (October 2021):**

# %%
# Look at October 2021 in more detail to allow a closer look.
# Create a lineplot.
nc_october = national_categories[(national_categories['appointment_date'] >='2021-10-01') & \
                                (national_categories['appointment_date'] <='2021-10-31')]

nc_october.groupby(['service_setting', 'appointment_date'])\
[['count_of_appointments']].sum().reset_index().copy()

nc_october.head()
# Out:
#      appointment_date icb_ons_code  \
# 1315       2021-10-01    E54000050
# 1316       2021-10-01    E54000050
# 1317       2021-10-01    E54000050
# 1318       2021-10-01    E54000050
# 1319       2021-10-01    E54000050
#
#                            sub_icb_location_name       service_setting  \
# 1315  NHS North East and North Cumbria ICB - 00L  Primary Care Network
# 1316  NHS North East and North Cumbria ICB - 00L  Primary Care Network
# 1317  NHS North East and North Cumbria ICB - 00L  Primary Care Network
# 1318  NHS North East and North Cumbria ICB - 00L  Primary Care Network
# 1319  NHS North East and North Cumbria ICB - 00L                 Other
#
#                 context_type  \
# 1315  Care Related Encounter
# 1316  Care Related Encounter
# 1317  Care Related Encounter
# 1318  Care Related Encounter
# 1319    Inconsistent Mapping
#
#                                               national_category  \
# 1315                               Structured Medication Review
# ...

# %%
plt.figure(figsize = (18, 6))

nc_plot = sns.lineplot(x='appointment_date', y='count_of_appointments', hue='service_setting',
                       data=nc_october, ci=None)
plt.title("Appointment count by service setting - October 2021")
plt.xlabel("Appointment Date", fontsize= 12)
plt.ylabel("Count of Appointments", fontsize= 12)
# Out:
# Text(0, 0.5, 'Count of Appointments')

# %% [markdown]
# **Winter (January 2022):**

# %%
# Look at January 2022 in more detail to allow a closer look.
# Create a lineplot.
nc_jan = national_categories[(national_categories['appointment_date'] >='2022-01-01') & \
                                (national_categories['appointment_date'] <='2022-01-31')]
nc_jan_appts = nc_jan.groupby(['service_setting', 'appointment_date'])\
[['count_of_appointments']].sum().reset_index().copy()

plt.figure(figsize = (18, 6))

nc_plot = sns.lineplot(x='appointment_date', y='count_of_appointments', hue='service_setting',
                       data=nc_jan_appts, ci=None)
plt.title("Appointment count by service setting - January 2022 ")
plt.xlabel("Appointment Date", fontsize= 12)
plt.ylabel("Count of Appointments", fontsize= 12)
# Out:
# Text(0, 0.5, 'Count of Appointments')

# %% [markdown]
# **Spring (April 2022):**

# %%
# Look at April 2022 in more detail to allow a closer look.
# Create a lineplot.
nc_april = national_categories[(national_categories['appointment_date'] >='2022-04-01') & \
                                (national_categories['appointment_date'] <='2022-04-30')]

nc_april_appts = nc_april.groupby(['service_setting', 'appointment_date'])\
[['count_of_appointments']].sum().reset_index().copy()

plt.figure(figsize = (18, 6))

nc_plot = sns.lineplot(x='appointment_date', y='count_of_appointments', hue='service_setting',
                       data=nc_april_appts, ci=None)
plt.title("Appointment count by service setting - April 2022")
plt.xlabel("Appointment Date", fontsize= 12)
plt.ylabel("Count of Appointments", fontsize= 12)
# Out:
# Text(0, 0.5, 'Count of Appointments')

# %%
# Look at Spring 2022 in more detail to allow a closer look.
# Create a lineplot.
nc_spring = national_categories[(national_categories['appointment_date'] >='2022-03-01') & \
                                (national_categories['appointment_date'] <='2022-05-31')]

nc_spring_appts = nc_spring.groupby(['service_setting', 'appointment_date'])\
[['count_of_appointments']].sum().reset_index().copy()

plt.figure(figsize = (18, 6))

nc_plot = sns.lineplot(x='appointment_date', y='count_of_appointments',data=nc_spring_appts, ci=None)
plt.title("Appointment count by service setting - Spring 2022")
plt.xlabel("Appointment Date", fontsize= 12)
plt.ylabel("Count of Appointments", fontsize= 12)
# Out:
# Text(0, 0.5, 'Count of Appointments')

# %% [markdown]
# # Assignment activity 5

# %% [markdown]
# ### Analyse tweets from Twitter with hashtags related to healthcare in the UK.

# %%
# Maximum column width to display
pd.options.display.max_colwidth = 200

# %%
# Load the data set.
tweets = pd.read_csv('tweets.csv')

# View the DataFrame.

print(tweets.shape)
print(tweets.dtypes)
tweets.head()
# Out:
# (1174, 10)
# tweet_id                    int64
# tweet_full_text            object
# tweet_entities             object
# tweet_entities_hashtags    object
# tweet_metadata             object
# tweet_retweet_count         int64
# tweet_favorite_count        int64
# tweet_favorited              bool
# tweet_retweeted              bool
# tweet_lang                 object
# dtype: object
#               tweet_id  \
# 0  1567629223795527681
# 1  1567582846612553728
# 2  1567582787070304256
# 3  1567582767625428992
# 4  1567582720460570625
#
#                                                                                                                                                                                            tweet_full_text  \
# 0  As Arkansas’ first Comprehensive Stroke Certified Center, UAMS provides Arkansans with access to the most advanced stoke care. Join us in our mission to make a difference in the health and well-be...
# ...

# %%
# Explore the metadata.
tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1174 entries, 0 to 1173
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tweet_id                 1174 non-null   int64
#  1   tweet_full_text          1174 non-null   object
#  2   tweet_entities           1174 non-null   object
#  3   tweet_entities_hashtags  1007 non-null   object
#  4   tweet_metadata           1174 non-null   object
#  5   tweet_retweet_count      1174 non-null   int64
#  6   tweet_favorite_count     1174 non-null   int64
#  7   tweet_favorited          1174 non-null   bool
#  8   tweet_retweeted          1174 non-null   bool
#  9   tweet_lang               1174 non-null   object
# dtypes: bool(2), int64(3), object(5)
# memory usage: 75.8+ KB

# %%
# Explore the data set.
tweets.describe()
# Out:
#            tweet_id  tweet_retweet_count  tweet_favorite_count
# count  1.174000e+03          1174.000000            1174.00000
# mean   1.567612e+18             8.629472               0.37138
# std    2.427553e+13            29.784675               2.04470
# min    1.567574e+18             0.000000               0.00000
# 25%    1.567590e+18             0.000000               0.00000
# 50%    1.567611e+18             1.000000               0.00000
# 75%    1.567633e+18             3.000000               0.00000
# max    1.567655e+18           303.000000              42.00000

# %%
# Would it be useful to only look at retweeted and favourite tweet messages?
# Explain your answer.

# %%
# Create a new DataFrame containing only the text.
tweets_text = tweets[['tweet_full_text']]

# View the DataFrame.
tweets_text.head(5)
# Out:
#                                                                                                                                                                                            tweet_full_text
# 0  As Arkansas’ first Comprehensive Stroke Certified Center, UAMS provides Arkansans with access to the most advanced stoke care. Join us in our mission to make a difference in the health and well-be...
# 1                                                              RT @AndreaGrammer: Work-life balance is at the foundation of how decisions are made and where #PremiseHealth is headed.  We're #hiring for…
# 2                                                           RT @OntarioGreens: $10 billion can go a long way to fixing our broken #Healthcare system.\n\nYet Doug Ford would rather spend it ALL on a hig…
# ...

# %%
# Loop through the messages, and create a list of values containing the # symbol.
tags = []

for y in [x.split(' ') for x in tweets['tweet_full_text'].values]:
    for z in y:
        if '#' in z:
            # Change to lowercase.
            tags.append(z.lower())

# %%
# Display the first 30 records.
print(tags[1:30])
# Out:
# ['#premisehealth', '#hiring', '#healthcare', '🚨#new:🚨', 'look!\n\n#blogs', '#digitaltransformation', '#cybersecurity', '#accounting', '#finance', '#healthcare', 'https://t.co/jrgqeqdme4\n.\n#firstcoastcna', '#cnaexam', '#cnaexampreparation', '#jacksonville', '#cnatraining', '#nurse', '#nursing', '#nurselife', '#nursepractitioner', '#nurseproblems', '#nursingschool', '#healthcare', '🚨#new:🚨', '#disparities.', '@karahartnett\n#healthcare', '#alert', '#insurance', '#data\nhttps://t.co/h9hlamr7p9', '#healthcare']

# %%
# Convert list to a series 
tags_series = pd.Series(tags)

tags_series
# Out:
# 0              #healthcare
# 1           #premisehealth
# 2                  #hiring
# 3              #healthcare
# 4                  🚨#new:🚨
#                ...
# 4328    #mediqueststaffing
# 4329             #hospital
# 4330                #shift
# 4331       (#newportbeach)
# 4332                  #job
# Length: 4333, dtype: object

# %%
# Use value_counts() to get a count of how often each tag appears
tag_count = tags_series.value_counts()

# %%
# Convert the series to a DataFrame in preparation for visualisation.
tweet_count = pd.DataFrame(tag_count)
tweet_count = tweet_count.reset_index()
tweet_count.columns = ['Hashtags', 'Count of Hashtags']

print(tweet_count.shape)
print(tweet_count.dtypes)
tweet_count.head(5)
# Out:
# (1754, 2)
# Hashtags             object
# Count of Hashtags     int64
# dtype: object
#       Hashtags  Count of Hashtags
# 0  #healthcare                716
# 1      #health                 80
# 2    #medicine                 41
# 3          #ai                 40
# 4         #job                 38

# %%
# Display records where the count is larger than 10
# Use tail() to check all tweets have at more than 10 records
popular_tweets = tweet_count.loc[tweet_count['Count of Hashtags'] > 10]

print(popular_tweets.shape)
popular_tweets.tail(5)
# Out:
# (47, 2)
#                     Hashtags  Count of Hashtags
# 42             #healthcareit                 11
# 43                      #usa                 11
# 44                   #nurses                 11
# 45  drugs\n\n#tipsfornewdocs                 11
# 46    #digitaltransformation                 11

# %%
# Check the top 5 tweets
popular_tweets.head(5)
# Out:
#       Hashtags  Count of Hashtags
# 0  #healthcare                716
# 1      #health                 80
# 2    #medicine                 41
# 3          #ai                 40
# 4         #job                 38

# %%
# Create a Seaborn barplot indicating records with a count >10 records.
# Colorblind palette used to improve readability
sns.set(rc={'figure.figsize':(15, 12)})

tweet_plot = sns.barplot(x="Hashtags", y='Count of Hashtags', estimator=sum, data=popular_tweets,
                        palette='colorblind')
plt.title("Most Popular Tweets", y=1.02, fontsize=16);
plt.xticks(rotation=90)
plt.xlabel("Popular Hashtags", fontsize= 12)
plt.ylabel("Count of Hashtags", fontsize= 12)
# Out:
# Text(0, 0.5, 'Count of Hashtags')

# %%
# Checking for outliers - Select hashtag count between 10 < 41 - removing two extreme outliers
# Create a boxplot to view skew of data
popular_tweets_filtered = popular_tweets[(popular_tweets['Count of Hashtags'] > 10)\
                                         & (popular_tweets['Count of Hashtags'] <= 41)]

fig = plt.figure(figsize=(18, 4))

sns.boxplot(data=popular_tweets_filtered, y='Count of Hashtags',  whis=1.5)
# Out:
# <AxesSubplot:ylabel='Count of Hashtags'>

# %% [markdown]
# The boxplot shows even removing the two extreme outliers that the majority of the hashtags have a median of 15.

# %%
# Create a Seaborn barplot indicating the top 10 hashtags 
# Slice the dataframe using iloc to first 10 records 
# Colorblind palette used to improve readability 
popular_tweets_filtered = popular_tweets_filtered.iloc[:10]

sns.set(rc={'figure.figsize':(15, 12)})

tweet_plot = sns.barplot(x='Hashtags', y='Count of Hashtags', estimator=sum, data=popular_tweets_filtered,
                        palette='colorblind')
plt.title("Most Popular Tweets", y=1.02, fontsize=16);
plt.xticks(rotation=90)
plt.xlabel("Popular Hashtags", fontsize= 12)
plt.ylabel("Count of Hashtags", fontsize= 12)

plt.savefig('pop_tweets_plot.jpg')

# %%
# Create a user defined function to search for tweets containing nhs
# Tweets returning any keywords could be searched by creating user defined function
def contains_nhs(x):
    """does the tweet contain nhs?"""
    y = x.lower()
    return "nhs" in y

# Check the function works as expected
print(contains_nhs(x="nhs"))
print(contains_nhs(x="NHS"))
print(contains_nhs(x="water"))
# Out:
# True
# True
# False

# %%
# Read tweets with NHS by applying contains_nhs function
nhs_tweets = tweets['tweet_full_text'].apply(contains_nhs)

print(nhs_tweets)
tweets[nhs_tweets]
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1169    False
# 1170    False
# 1171    False
# 1172    False
# 1173    False
# Name: tweet_full_text, Length: 1174, dtype: bool
#                 tweet_id  \
# 200  1567654557768982529
# 231  1567652040192532480
# 450  1567633960879984640
#
#                                                                                                                                                                                              tweet_full_text  \
# 200                                                           RT @LaunchpadDevon: @RDCareersNHS  Recruitment Event  Exeter – Saturday 17 September\n\nThis event is for anyone interested in roles availabl…
# 231                                                           RT @SkillsLaunchpad: Recruitment Event  Exeter – Saturday 17 September with @RDCareersNHS  \n\nFor anyone interested in #administration #heal…
# ...

# %% [markdown]
# # Assignment activity 6

# %% [markdown]
# ### Investigate the main cencerns posed by the NHS.

# %%
# View the appointments_regional DataFrame
print(appointments_regional.shape)
print(appointments_regional.dtypes)
appointments_regional.head()
# Out:
# (596821, 7)
# icb_ons_code                                 object
# appointment_month                    datetime64[ns]
# appointment_status                           object
# hcp_type                                     object
# appointment_mode                             object
# time_between_book_and_appointment            object
# count_of_appointments                         int64
# dtype: object
#   icb_ons_code appointment_month appointment_status hcp_type appointment_mode  \
# 0    E54000034        2020-01-01           Attended       GP     Face-to-Face
# 1    E54000034        2020-01-01           Attended       GP     Face-to-Face
# 2    E54000034        2020-01-01           Attended       GP     Face-to-Face
# 3    E54000034        2020-01-01           Attended       GP     Face-to-Face
# 4    E54000034        2020-01-01           Attended       GP     Face-to-Face
#
#   time_between_book_and_appointment  count_of_appointments
# ...

# %%
# Print the min and max dates.
print(appointments_regional['appointment_month'].max())
print(appointments_regional['appointment_month'].min())
# Out:
# 2022-06-01 00:00:00
# 2020-01-01 00:00:00

# %%
# Filter the data set to only look at data from 2021-08 onwards.
ar_filtered = appointments_regional[appointments_regional['appointment_month'] >='2021-08']

ar_filtered.head()
# Out:
#      icb_ons_code appointment_month appointment_status hcp_type  \
# 3652    E54000034        2021-08-01           Attended       GP
# 3653    E54000034        2021-08-01           Attended       GP
# 3654    E54000034        2021-08-01           Attended       GP
# 3655    E54000034        2021-08-01           Attended       GP
# 3656    E54000034        2021-08-01           Attended       GP
#
#      appointment_mode time_between_book_and_appointment  count_of_appointments
# 3652     Face-to-Face                             1 Day                   6553
# 3653     Face-to-Face                    15  to 21 Days                   2390
# 3654     Face-to-Face                       2 to 7 Days                  10547
# 3655     Face-to-Face                    22  to 28 Days                    937
# 3656     Face-to-Face                     8  to 14 Days                   4961

# %%
# View the status of appointments in the AR dataset 
ar_status = ar_filtered.groupby(['appointment_status'])[['count_of_appointments']]\
.sum().reset_index().copy()

ar_status.head()
# Out:
#   appointment_status  count_of_appointments
# 0           Attended              270657694
# 1                DNA               13318384
# 2            Unknown               12070692

# %%
# Worked out the total count of appointments 
total = ar_status['count_of_appointments'].sum()

print(total)
# Out:
# 296046770

# %%
# Create a barplot of the appointment status including % of the total count of appointments
status_plot = sns.barplot(x='appointment_status', y='count_of_appointments', data=ar_status)
plt.title("Count of Appointment by Status")
status_plot.set_xlabel("Appointment Status")
status_plot.set_ylabel("Count of Appointments")

total = (ar_status['count_of_appointments'].sum())

for p in status_plot.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x()
    y = p.get_y() + p.get_height()
    status_plot.annotate(percentage, (x, y),verticalalignment='bottom',horizontalalignment='left',
                        bbox={'boxstyle': 'circle, pad=3', 'fill': False})
plt.show()
plt.savefig('appt_statusplot.jpg')

# %% [markdown]
# **Question 1:** Should the NHS start looking at increasing staff levels?

# %%
# Create an aggregated data set to determine the total number of appointments per month.
ar_agg = ar_filtered.groupby(['appointment_month'])[['count_of_appointments']]\
.sum().reset_index().copy()

# View the DataFrame.
print(ar_agg.dtypes)
ar_agg
# Out:
# appointment_month        datetime64[ns]
# count_of_appointments             int64
# dtype: object
#    appointment_month  count_of_appointments
# 0         2021-08-01               23852171
# 1         2021-09-01               28522501
# 2         2021-10-01               30303834
# 3         2021-11-01               30405070
# 4         2021-12-01               25140776
# 5         2022-01-01               25635474
# 6         2022-02-01               25355260
# 7         2022-03-01               29595038
# 8         2022-04-01               23913060
# 9         2022-05-01               27495508
# 10        2022-06-01               25828078

# %%
# Add a new column to indicate the average utilisation of services.
# Monthly aggregate / 30 to get to a daily value.
ar_agg['utilisation'] = ar_agg['count_of_appointments'] / 30
ar_agg['utilisation'] = ar_agg['utilisation'].round(decimals = 0)

# View the DataFrame.
print(ar_agg.dtypes)
ar_agg
# Out:
# appointment_month        datetime64[ns]
# count_of_appointments             int64
# utilisation                     float64
# dtype: object
#    appointment_month  count_of_appointments  utilisation
# 0         2021-08-01               23852171     795072.0
# 1         2021-09-01               28522501     950750.0
# 2         2021-10-01               30303834    1010128.0
# 3         2021-11-01               30405070    1013502.0
# 4         2021-12-01               25140776     838026.0
# 5         2022-01-01               25635474     854516.0
# 6         2022-02-01               25355260     845175.0
# 7         2022-03-01               29595038     986501.0
# 8         2022-04-01               23913060     797102.0
# 9         2022-05-01               27495508     916517.0
# 10        2022-06-01               25828078     860936.0

# %%
# Change the datatype of utilisation to int64 for plotting
ar_agg['utilisation'].astype('int64')
# Out:
# 0      795072
# 1      950750
# 2     1010128
# 3     1013502
# 4      838026
# 5      854516
# 6      845175
# 7      986501
# 8      797102
# 9      916517
# 10     860936
# Name: utilisation, dtype: int64

# %%
# Plot sum of count of monthly visits.
# Create a lineplot with Seaborn.

plt.figure(figsize = (18, 6))
monthly_appts = sns.lineplot(x='appointment_month', y='count_of_appointments', data=ar_agg, ci=None,
                             markers="o")
plt.title("Monthly Appointments", fontsize= 16)
plt.xlabel("Appointment Month", fontsize= 12)
plt.ylabel("Count of Appointments (Tens of Millions)", fontsize= 12)

monthly_appts.annotate('2021-12', xy=(5,25140776))
# Out:
# Text(5, 25140776, '2021-12')

# %%
# Plot monthly capacity utilisation.
# Create a lineplot.
plt.figure(figsize = (18, 6))
monthly_use = sns.lineplot(x='appointment_month', y='utilisation', data=ar_agg, ci=None)
plt.title("Average Daily Utilisation by Month", fontsize= 16)
plt.xlabel("Appointment Month", fontsize= 12)
plt.ylabel("Count of Appointments (Tens of Millions)", fontsize= 12)
plt.axhline(y=1200000, xmin=0, xmax=1, c="green", linestyle='--')

plt.savefig('utilisation_plot.jpg')

# %% [markdown]
# **Question 2:** How do the healthcare professional types differ over time?

# %%
# Create a line plot to answer the question.
hcp_appts = ar_filtered.groupby(['hcp_type', 'appointment_month'])[['count_of_appointments']]\
.sum().reset_index().copy()

hcp = sns.lineplot(x='appointment_month', y='count_of_appointments', hue='hcp_type',\
                   data=hcp_appts[hcp_appts['hcp_type'] != 'Unknown'], ci=None)
plt.title("Monthly Appointment Count by Health Care Professional")
plt.xlabel("Appointment Month", fontsize= 12)
plt.ylabel("Count of Appointments (Tens of Millions)", fontsize= 12)
# Out:
# Text(0, 0.5, 'Count of Appointments (Tens of Millions)')

# %%
# What mode of appointments are most common by Healthcare Professional Type? 
mode_appts = ar_filtered.groupby(['hcp_type','appointment_mode'])[['count_of_appointments']]\
.sum().reset_index().copy()

hcp = sns.barplot(x='appointment_mode', y='count_of_appointments', hue='hcp_type',\
                   data=mode_appts)
plt.title("Appointment Count by Mode", fontsize= 20)
plt.xlabel("Appointment Mode", fontsize= 12)
plt.ylabel("Count of Appointments (Tens of Millions)", fontsize= 12)

plt.savefig('appt_mode_plot.jpg')

# %%
# What mode of did not appointments are most common by Healthcare Professional Type? 
dnamode_appts = ar_filtered[ar_filtered['appointment_status'] != 'DNA']

hcp = sns.barplot(x='appointment_mode', y='count_of_appointments', hue='hcp_type',\
                   data=dnamode_appts)
plt.title("Mode of Did Not Attend Appointment Count", fontsize= 20)
plt.xlabel("Appointment Mode", fontsize= 12)
plt.ylabel("Count of Appointments", fontsize= 12)

plt.savefig('dna_mode_plot.jpg')

# %%
lead_ar_filtered = ar_filtered[ar_filtered['time_between_book_and_appointment'] != 'Unknown / Data Quality']

lead_ar_filtered.head()
# Out:
#      icb_ons_code appointment_month appointment_status hcp_type  \
# 3652    E54000034        2021-08-01           Attended       GP
# 3653    E54000034        2021-08-01           Attended       GP
# 3654    E54000034        2021-08-01           Attended       GP
# 3655    E54000034        2021-08-01           Attended       GP
# 3656    E54000034        2021-08-01           Attended       GP
#
#      appointment_mode time_between_book_and_appointment  count_of_appointments
# 3652     Face-to-Face                             1 Day                   6553
# 3653     Face-to-Face                    15  to 21 Days                   2390
# 3654     Face-to-Face                       2 to 7 Days                  10547
# 3655     Face-to-Face                    22  to 28 Days                    937
# 3656     Face-to-Face                     8  to 14 Days                   4961

# %%
# Define a function to map the values
def set_timevalue(row_number, assigned_value):
    return assigned_value[row_number]

lead_dictionary ={'1 Day' : 2, 'Same Day' : 1, '2 to 7 Days' : 7, '22  to 28 Days' : 28, 
                  '8  to 14 Days' : 14, '15  to 21 Days' : 21,'More than 28 Days' : 31, 'Unknown/Data Quality': 100}

lead_ar_filtered['lead_time'] = lead_ar_filtered['time_between_book_and_appointment'].\
apply(set_timevalue, args =(lead_dictionary,))
 
# Print the DataFrame
print(lead_ar_filtered.dtypes)
lead_ar_filtered.head()
# Out:
# icb_ons_code                                 object
# appointment_month                    datetime64[ns]
# appointment_status                           object
# hcp_type                                     object
# appointment_mode                             object
# time_between_book_and_appointment            object
# count_of_appointments                         int64
# lead_time                                     int64
# dtype: object
# /var/folders/3g/t377cwrj5ngf1xjpm17x6sgc0000gn/T/ipykernel_18951/1838599787.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lead_ar_filtered['lead_time'] = lead_ar_filtered['time_between_book_and_appointment'].\
#      icb_ons_code appointment_month appointment_status hcp_type  \
# ...

# %%
lead_time = sns.barplot(x='lead_time', y='count_of_appointments', hue='appointment_mode',\
                   data=lead_ar_filtered)
plt.title("Appointment Count by Booking Time", fontsize= 20)
plt.xlabel("Appointment Booking Lead Time", fontsize= 12)
plt.ylabel("Count of Appointments", fontsize= 12)
lead_time.set_xticklabels(['Same Day','1 Day','2 to 7 Days','8 to 14 Days','15 to 21 Days','22 to 28 Days','More than 28 Days'])
plt.savefig('lead_booking_plot.jpg')

# %% [markdown]
# **Question 3:** Are there significant changes in whether or not visits are attended?

# %%
# Non-attended appointments
dna = ar_filtered[(ar_filtered['appointment_status'] == 'DNA') &
                 (ar_filtered['time_between_book_and_appointment'] != 'Unknown / Data Quality')]
dna.head()
# Out:
#      icb_ons_code appointment_month appointment_status hcp_type  \
# 3730    E54000034        2021-08-01                DNA       GP
# 3731    E54000034        2021-08-01                DNA       GP
# 3732    E54000034        2021-08-01                DNA       GP
# 3733    E54000034        2021-08-01                DNA       GP
# 3734    E54000034        2021-08-01                DNA       GP
#
#      appointment_mode time_between_book_and_appointment  count_of_appointments
# 3730     Face-to-Face                             1 Day                    259
# 3731     Face-to-Face                    15  to 21 Days                    175
# 3732     Face-to-Face                       2 to 7 Days                    536
# 3733     Face-to-Face                    22  to 28 Days                     78
# 3734     Face-to-Face                     8  to 14 Days                    335

# %%
# Define a function to map the values
dna['lead_time'] = dna['time_between_book_and_appointment'].apply(set_timevalue, args =(lead_dictionary,))
 
# Print the DataFrame
print(dna.dtypes)
dna.head()
# Out:
# icb_ons_code                                 object
# appointment_month                    datetime64[ns]
# appointment_status                           object
# hcp_type                                     object
# appointment_mode                             object
# time_between_book_and_appointment            object
# count_of_appointments                         int64
# lead_time                                     int64
# dtype: object
# /var/folders/3g/t377cwrj5ngf1xjpm17x6sgc0000gn/T/ipykernel_18951/2779402752.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dna['lead_time'] = dna['time_between_book_and_appointment'].apply(set_timevalue, args =(lead_dictionary,))
# ...

# %%
lead_time = sns.barplot(x='lead_time', y='count_of_appointments', \
                   data=dna)
plt.title("DNA Appointment Count by Booking Time", fontsize= 20)
plt.xlabel("Appointment Booking Lead Time", fontsize= 12)
plt.ylabel("Count of Appointments", fontsize= 12)
lead_time.set_xticklabels(['Same Day','1 Day','2 to 7 Days','8 to 14 Days','15 to 21 Days','22 to 28 Days','More than 28 Days'])
plt.savefig('dna_lead_booking_plot.jpg')

# %%
sns.barplot(x='lead_time', y='count_of_appointments', hue='hcp_type', estimator=sum, data=dna)

plt.title("Lead Time for Appointments Not Attended ", fontsize= 20)
plt.xlabel("Lead Time between Booking and Appointment ", fontsize= 12)
plt.ylabel("Count of Appointments", fontsize= 12)
lead_time.set_xticklabels(['Same Day','1 Day','2 to 7 Days','8 to 14 Days','15 to 21 Days','22 to 28 Days',
                           'More than 28 Days'])
plt.savefig('DNA_Hcp.jpg')

# %%
# Check which 
sns.barplot(x='appointment_mode', y='count_of_appointments', hue='appointment_status', estimator=sum,
            data=ar_filtered)
# Out:
# <AxesSubplot:xlabel='appointment_mode', ylabel='count_of_appointments'>

# %%
# Check which modes of appointment are most likely not to occur
sns.barplot(x='appointment_mode', y='count_of_appointments', hue='hcp_type', estimator=sum,
            data=dna)
# Out:
# <AxesSubplot:xlabel='appointment_mode', ylabel='count_of_appointments'>

# %%
# What is the average duration of appointments? 
known_duration = actual_duration[actual_duration['actual_duration'] != 'Unknown / Data Quality']

sns.barplot(x='actual_duration', y='count_of_appointments', estimator=sum, 
            data=known_duration)

plt.title("Duration of Appointments", fontsize=16)
status_plot.set_xlabel("Appointment Length (minutes)", fontsize=12)
status_plot.set_ylabel("Count of Appointments", fontsize=12)
plt.savefig('duration_plot.jpg')

# %%
known_duration.head()
# Out:
#   sub_icb_location_code sub_icb_location_ons_code  \
# 0                   00L                 E38000130
# 1                   00L                 E38000130
# 2                   00L                 E38000130
# 4                   00L                 E38000130
# 5                   00L                 E38000130
#
#                         sub_icb_location_name icb_ons_code region_ons_code  \
# 0  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 1  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 2  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 4  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 5  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
#
#   appointment_date actual_duration  count_of_appointments
# 0       2021-12-01   31-60 Minutes                    364
# 1       2021-12-01   21-30 Minutes                    619
# ...

# %%
# What are  of appointments? 
known_duration = actual_duration[actual_duration['actual_duration'] != 'Unknown / Data Quality']

sns.barplot(x='actual_duration', y='count_of_appointments', estimator=sum, 
            data=known_duration)

plt.title("Duration of Appointments", fontsize=16)
status_plot.set_xlabel("Appointment Length (minutes)", fontsize=12)
status_plot.set_ylabel("Count of Appointments", fontsize=12)
# Out:
# Text(17.246875000000017, 0.5, 'Count of Appointments')

# %%
known_duration.dtypes
# Out:
# sub_icb_location_code                object
# sub_icb_location_ons_code            object
# sub_icb_location_name                object
# icb_ons_code                         object
# region_ons_code                      object
# appointment_date             datetime64[ns]
# actual_duration                      object
# count_of_appointments                 int64
# dtype: object

# %%
# Define a function to map the values
def set_value(row_number, assigned_value):
    return assigned_value[row_number]

duration_dictionary ={'1-5 Minutes' : 1, '6-10 Minutes' : 6, '11-15 Minutes' : 11,
                     '16-20 Minutes' : 16, '21-30 Minutes' : 21, '31-60 Minutes' : 31 }

known_duration['min_duration'] = known_duration['actual_duration'].apply(set_value, args =(duration_dictionary, ))
 
# Print the DataFrame
print(known_duration.dtypes)
known_duration.head()
# Out:
# sub_icb_location_code                object
# sub_icb_location_ons_code            object
# sub_icb_location_name                object
# icb_ons_code                         object
# region_ons_code                      object
# appointment_date             datetime64[ns]
# actual_duration                      object
# count_of_appointments                 int64
# min_duration                          int64
# dtype: object
# /var/folders/3g/t377cwrj5ngf1xjpm17x6sgc0000gn/T/ipykernel_18951/2013634354.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   known_duration['min_duration'] = known_duration['actual_duration'].apply(set_value, args =(duration_dictionary, ))
#   sub_icb_location_code sub_icb_location_ons_code  \
# ...

# %%
ax = sns.barplot(x='min_duration', y='count_of_appointments', data=known_duration)

plt.title("Duration of Appointments", fontsize=16)
status_plot.set_xlabel("Appointment Length (minutes)", fontsize=12)
status_plot.set_ylabel("Count of Appointments", fontsize=12)
ax.set_xticklabels(['1-5','6-10','11-15','16-20','21-30','31-60'])
plt.title("Count of Appointments by Duration", fontsize= 20)
plt.xlabel("Appointment Duration (Minutes)", fontsize= 12)
plt.ylabel("Count of Appointments", fontsize= 12)
plt.savefig('duration_plot.jpg')

# %%
# Create a boxplot to view outliers of the appointment_duration 
sns.boxplot(data=known_duration, x='actual_duration', y='count_of_appointments', whis=1.5)
plt.title("Appointment Duration", fontsize= 16)
plt.xlabel("Appointment Length (min)", fontsize= 12)
plt.ylabel("Count of Appointments ()", fontsize= 12)
# Out:
# Text(0, 0.5, 'Count of Appointments ()')

# %% [markdown]
# **Question 4:** Are there changes in terms of appointment type and the busiest months?

# %%
nov_duration = actual_duration.loc[actual_duration['appointment_date'].between('2022-01-01','2022-06-01')]

nov_duration.head()
# Out:
#     sub_icb_location_code sub_icb_location_ons_code  \
# 170                   00L                 E38000130
# 171                   00L                 E38000130
# 172                   00L                 E38000130
# 173                   00L                 E38000130
# 174                   00L                 E38000130
#
#                           sub_icb_location_name icb_ons_code region_ons_code  \
# 170  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 171  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 172  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 173  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 174  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
#
#     appointment_date         actual_duration  count_of_appointments
# 170       2022-01-03  Unknown / Data Quality                      1
# ...

# %%
sns.scatterplot(x='appointment_date', y='count_of_appointments', hue='actual_duration', 
                data=nov_duration[nov_duration['actual_duration'] != 'Unknown / Data Quality'])

plt.title("Appointment Service Settings November 2021")
plt.xlabel("Appointment Dates - November 2021", fontsize= 12)
plt.ylabel("Count of Appointments", fontsize= 12)
# Out:
# Text(0, 0.5, 'Count of Appointments')

# %% [markdown]
# **Question 5:** Are there any trends in time between booking an appointment?

# %%
# Create a line plot to answer the question.
ar_filtered.head()
# Out:
#      icb_ons_code appointment_month appointment_status hcp_type  \
# 3652    E54000034        2021-08-01           Attended       GP
# 3653    E54000034        2021-08-01           Attended       GP
# 3654    E54000034        2021-08-01           Attended       GP
# 3655    E54000034        2021-08-01           Attended       GP
# 3656    E54000034        2021-08-01           Attended       GP
#
#      appointment_mode time_between_book_and_appointment  count_of_appointments
# 3652     Face-to-Face                             1 Day                   6553
# 3653     Face-to-Face                    15  to 21 Days                   2390
# 3654     Face-to-Face                       2 to 7 Days                  10547
# 3655     Face-to-Face                    22  to 28 Days                    937
# 3656     Face-to-Face                     8  to 14 Days                   4961

# %%
sns.scatterplot(x='time_between_book_and_appointment', y='count_of_appointments', marker='o',
               hue='appointment_status',
               legend='full', data=ar_filtered)
# Out:
# <AxesSubplot:xlabel='time_between_book_and_appointment', ylabel='count_of_appointments'>

# %% [markdown]
# **Question 6:** How do the spread of service settings compare?

# %%
# Let's go back to the national category DataFrame you created in an earlier assignment activity.

# %%
# Create a new DataFrame consisting of the month of appointment and the number of appointments.
nc_appts = national_categories.groupby(['service_setting'])[['count_of_appointments']]\
.sum().reset_index().copy()

nc_appts.head()
# Out:
#              service_setting  count_of_appointments
# 0  Extended Access Provision                2176807
# 1           General Practice              270811691
# 2                      Other                5420076
# 3       Primary Care Network                6557386
# 4                   Unmapped               11080810

# %%
# Create a boxplot to investigate spread of service settings.
plt.figure(figsize = (18, 10))

sns.boxplot(x='service_setting', y='count_of_appointments', data=nc_appts)
plt.title("Monthly Appointment Count")
# Out:
# Text(0.5, 1.0, 'Monthly Appointment Count')

# %%
# Create a boxplot to investigate the service settings without GP.
nogp_nc = national_categories.loc[national_categories["service_setting"] != 'General Practice']

plt.figure(figsize = (18, 10))

sns.boxplot(x='service_setting', y='count_of_appointments', data=nogp_nc)
plt.title("Monthly Appointment Count")
# Out:
# Text(0.5, 1.0, 'Monthly Appointment Count')

# %%
# Plot the non-gp service settings data
nogp_nc = national_categories[national_categories['service_setting'] != 'General Practice']

non_gp = nogp_nc.groupby(['appointment_month', 'service_setting'])[['count_of_appointments']]\
.sum().sort_values('appointment_month', ascending=False)

plt.figure(figsize = (18, 6))

sns.lineplot(x='appointment_month', y='count_of_appointments', hue='service_setting', data=non_gp, ci=None)
plt.title("Monthly Appointment Count")
plt.xlabel("Appointment Month", fontsize= 12)
plt.ylabel("Count of Appointments", fontsize= 12)
# Out:
# Text(0, 0.5, 'Count of Appointments')
